# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanBarros2/NLP/blob/master/Agrupando_letras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Agrupando letras de Rock
#
# Letras de músicas segundo o vagalume.com.br, coletadas por Anderson Neisse e [disponíveis no kaggle](https://www.kaggle.com/neisse/scrapped-lyrics-from-6-genres/data).
#
# Os dados originais foram tratados para diminuir duplicações e diminuir o tamanho do arquivo. Os resultados (e outros recortes dos dados de letras) estão [nesse repo](https://github.com/nazareno/palavras-nas-letras).

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
letras = pd.read_csv('https://raw.githubusercontent.com/nazareno/palavras-nas-letras/master/letras-ptbr-rock-grande.csv')

letras.size
# Out:
# 53760

# %%
letras['Artist'].value_counts()[0:20]
# Out:
# Lulu Santos                462
# Engenheiros do Hawaii      402
# Jota Quest                 296
# Skank                      290
# Rita Lee                   282
# Erasmo Carlos              236
# Cássia Eller               226
# Titãs                      209
# Charlie Brown Jr           198
# Raul Seixas                196
# Capital Inicial            195
# Biquini Cavadão            184
# Os Paralamas do Sucesso    181
# Barão Vermelho             164
# Velhas Virgens             156
# Fresno                     153
# Blitz                      150
# Pato Fu                    146
# Ira!                       142
# Rosa de Saron              137
# Name: Artist, dtype: int64

# %% [markdown]
# ## Pré processamento do texto

# %%
stop_words = set(stopwords.words("portuguese"))
print(len(stop_words))
# Out:
# 204

# %%
#construct a new list to store the cleaned text
clean_lyrics = []
for w in range(len(letras.Lyric)):
    lyric = letras['Lyric'][w]

    #remove special characters and digits
    lyric  = re.sub("(\\d|\\W)+|\w*\d\w*"," ",lyric )
    lyric = ' '.join(s for s in lyric.split() if (not any(c.isdigit() for c in s)) and len(s) > 2)
    clean_lyrics.append(lyric)

clean_lyrics[0:10]
# Out:
# ['Enquanto ela estiver aqui Ainda haverá amor Com ela estou feliz com ela enfrento dor Não adianta fugir não adianta chorar dia ela sumir nada mais irá sobrar Sonhar viver todo dia agradecer rezar pra você ser última morrer Podem tentar atingir Podem mandar pra onde for Enquanto ela estiver aqui vida ainda tem valor Sonhar viver todo dia agradecer rezar pra você ser última morrer Uma gota você vale mais que tudo Quando solução não pode resolver fico com você esperança fico com você Sonhar viver todo dia agradecer rezar pra você ser última morrer Sonhar viver todo dia agradecer rezar pra você ser última morrer esperança Esperança',
#  'deu luz fez sonhar Chorou por mim fez amar Foi pra mim Foi tudo mais pouco enfim Canto quando sinto sua falta Rezo pelo bem sua alma queria que você vivesse mais vida levou deixou aqui que você ensinou que faz feliz Que Deus bom lugar guarde pra mim quando for minha vez encontro por Fale mais Quero ouvir Onde está Não vejo mas pra sentir Foi pra mim Foi tudo mais pouco enfim Canto quando sinto sua falta Rezo pelo bem sua alma queria que você vivesse mais vida levou deixou aqui que você ensinou que faz feliz Que Deus bom lugar guarde pra mim quando for minha vez encontro por',
#  'Nasce uma criança tem que acreditar Que força esperança continua transformar sonho realidade medo salvação Com musica batendo dentro meu coração vou viver Pra ser feliz Onde estiver Paz amor Não perca Reze pra Deus iluminar Todo caminho por onde passar Sei que difícil mundo guerra Com tanta violência Mas amor nunca entrega luta pela vida sigo missão Com musica batendo dentro meu coração vou viver vamos viver Pra ser feliz Onde estiver Paz amor Não perca Reze pra Deus iluminar Todo caminho por onde passar Felicidade vem encontrar Faz tua casa meu lar meu lar Pra onde você for leva que vou com você Pra ser feliz Onde estiver Paz amor Não perca Reze pra Deus iluminar Todo caminho por onde passar Olho pro céu peço mais paciência Pois tenho andado outra frequência Pra não fraquejar hora Não entregar ouro agora Trabalhar pra ganhar pra viver lugar legal Pra sair com você Entender que mundo cheio gente Mas nem todo mundo igual gente Paz amor pra não perde Chega outro lado carro Aliados lado lado Musica alma fica ligado fica ligado Paz amor',
#  'Deixa rolar Deixa fluir não deixe aprender Pode voltar pode confundir depende você Águas passadas irão afogar alguém Que desistiu lutar Seja forte não deixe levar Pois fraqueza mal querendo entrar Quem foi que disse que seria fácil dificuldade engrandece conquista Debaixo ponte espero tempestade Mas quando ela passar dou volta por cima Águas passadas irão afogar alguém Que desistir lutar Seja forte não deixe levar Pois fraqueza mal querendo entrar Não deixe ele entrar Vivo momento antes que tempo possa acabar Águas passadas irão afogar alguém Que desistir lutar Seja forte não deixe levar Pois fraqueza mal querendo Mas não deixo ele entrar',
#  'Para pensa Onde está seu verdadeiro amor não for ele então esqueça Nada deve ter tanto valor Enquanto não houver verdadeiro amor Que gente encontrou Você quer quero também Mas medo errar nos afasta Fechar olhos não adianta sei Então saiba que vou estar sempre ali seu coração que outros vão dizer não sei não importa que outros vão pensar não vou preocupar Esquece mundo lembra mim Não faça que você não está fim Você quer quero também Mas medo errar nos afasta Fechar olhos não adianta sei Então saiba que vou estar sempre ali seu coração Para pensa Você quer quero também Mas medo errar nos afasta Fechar olhos não adianta sei Então saiba que vou estar sempre ali Você quer quero também Mas medo errar nos afasta Fechar olhos não adianta sei Então saiba que vou estar sempre ali seu coração',
#  'Saudade Espero que logo logo vai passar Vontade Hoje quero matar com você Sempre que puder voltarei aqui Sempre que puder quero ver sorrir Felicidade vale tiver alguém pra dividir vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração Não quero estar sozinho vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração levo comigo aprendi usar solidão vivo bem comigo mesmo então Respeito com liberdade Onde estiver seja bem vinda agora você quiser Sempre que puder voltarei aqui Sempre que puder quero ver sorrir Felicidade vale tiver alguém pra dividir vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração Não quero estar sozinho vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração levo comigo vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração Não quero estar sozinho vou levar pra ver sol pra ver mar Andar meu caminho levo emoção pra acelerar meu coração levo comigo',
#  'Histórias antigas não vão abalar vida não para vou continuar porque Hoje Hoje resolvi mudar Mágoas problemas não vou nem pensar vida tão simples pra que complicar Então Hoje Hoje resolvi mudar que passou passou não vai voltar Esqueço aquilo que fiz Procuro novo amor velha paz tudo que faz feliz nuvens vão sol vem mas nem tudo volta pro seu lugar hoje resolvi mudar que passou passou não vai voltar Esqueço aquilo que fiz Procuro novo amor velha paz tudo que faz feliz que passou passou não vai voltar Esqueço aquilo que fiz Procuro novo amor velha paz tudo que faz feliz Resolvi mudar resolvi mudar Pra continuar vivendo feliz Resolvi mudar resolvi mudar',
#  'Ontem sonho acabou Mas vida continua vou estar sorrindo isso não quer dizer que não possa mais sonhar Preciso ser mais continuar sorrindo Sou mais forte Vou viver bem melhor Refrão Ontem sonho acabou Mas vida continua vou estar sorrindo isso não quer dizer que não possa mais sonhar Preciso ser mais continuar sorrindo veneno que jogaram minha alegria Virou soro contra toda tristeza Ganho mais dia minha vida Agradeço vou atrás sorrindo Sou mais forte Vou viver bem melhor Refrão Ontem sonho acabou Mas vida continua vou estar sorrindo isso não quer dizer que não possa mais sonhar Preciso ser mais continuar sorrindo',
#  'vim pra ser feliz vim pra ajudar pro que faz sorrir pro que faz sonhar Tudo que sei então levanto mão pro céu agradeço aquele que deu luz saúde paz Porque gente bicho solto mundo anda muito louco tudo violento demais sobrevivente guerra acendi uma vela pedi refrão salve paz salve amor coisas boas vida céu mar praia som surf sexo bom Deus família lar nada mais vai faltar prefiro evitar abusei minha vida passada aprendi também não quero contar com sorte todo momento tenho então levanto mão pro céu agradeço aquele que deu luz saúde paz Porque gente bicho solto mundo anda muito louco tudo violento demais sobrevivente guerra acendi uma vela pedi salve paz salve amor coisas boas vida céu mar praia som surf sexo bom Deus família lar nada mais vai faltar salve paz salve amor coisas boas vida céu mar praia som surf sexo bom Deus família lar nada mais vai faltar nada mais vai faltar salve paz salve amor coisas boas vida salve paz salve amor coisas boas vida',
#  'Foi assim que senhor razão falou Não fique triste estamos bem longe fim Sem motivo pra preocupar com coisas que vão resolver com tempo quem sou pra negar você pediu quem sou pra negar dou todo tempo que você precisar pra reencontrar que esse tempo guarde toda boa lembrança que gente viveu melhor que ficarmos juntos acabar uma vez sem querer relembrar nossa historia que ninguém ninguém vai conseguir apagar Vai passar quando chuva for tempo vai mostrar sol que estava escondido sempre vai voltar quem sou pra negar você pediu quem sou pra negar dou todo tempo que você precisar pra reencontrar que esse tempo guarde toda boa lembrança que gente viveu melhor que ficarmos juntos acabar uma vez sem querer relembrar nossa historia que ninguém ninguém vai conseguir apagar você pediu quem sou pra negar você pediu quem sou pra negar dou todo tempo que você precisar pra reencontrar que esse tempo guarde toda boa lembrança que gente viveu melhor que ficarmos juntos acabar uma vez sem querer relembrar sempre vou relembrar nossa historia que ninguém Ninguém vai conseguir apagar Ninguém vai conseguir apagar Ninguém vai conseguir apagar']

# %% [markdown]
# ## Vetores TF-IDF

# %%
#TF-IDF vectorizer
tfv = TfidfVectorizer(
        min_df = 10,
        max_df = 0.5,
        max_features = None,
        stop_words = stop_words, 
        ngram_range = (1,3)
  )

#transform
vec_text = tfv.fit_transform(clean_lyrics)

#returns a list of words.
words = tfv.get_feature_names()

len(words)
# Out:
# 8525

# %%
words[1:100]

# %% [markdown]
# ## Agrupamento
#
# ### Decidindo K

# %%
from sklearn.cluster import MiniBatchKMeans

# escolhendo k
qualidade = pd.DataFrame(columns = ['k', 'ssd'])
for k in range(1,170, 1):
  # kmeans = KMeans(n_clusters=k, random_state=0)
  kmeans = MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20)
  kmeans.fit(vec_text)
  qualidade = qualidade.append({'k': k, 'ssd' : kmeans.inertia_}, ignore_index=True)

alt.Chart(qualidade).mark_line(
    point=True
).encode(
    x = 'k',
    y = alt.Y('ssd', scale = alt.Scale(zero=False))
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Agrupando com o K escolhido

# %%
kmeans = MiniBatchKMeans(n_clusters=17, init_size=1024, batch_size=2048, random_state=20)
#fit the data 
kmeans.fit(vec_text)
labels = kmeans.predict(vec_text)

letras_ag = letras.assign(grupo = labels)

letras_ag.sample(10)
# Out:
#                                              SName  ... grupo
# 2516                             O Tudo Que É Nada  ...    10
# 6645               São Paulo Meu Amor Minha Menina  ...    10
# 1813                          Análise Descontraída  ...     8
# 5571                                        Chance  ...     1
# 5439                                           Tão  ...    13
# 1909                               Minha Superstar  ...     8
# 5303                               Entre Sem Bater  ...     8
# 6447  E o Meu Peito Mais Aberto Que o Mar da Bahia  ...     1
# 2623                        Me Adora (Part. Pitty)  ...     8
# 3290                                   Inestimável  ...    10
#
# [10 rows x 8 columns]

# %% [markdown]
# ## Interpretando os grupos

# %%
letras_ag['grupo'].value_counts()
# Out:
# 8     2815
# 1     1214
# 9      683
# 6      612
# 10     591
# 4      333
# 13     257
# 14     167
# 7      155
# 15     141
# 11     132
# 16     124
# 2      119
# 3      103
# 12      91
# 0       80
# 5       63
# Name: grupo, dtype: int64

# %%
#this loop transforms the numbers back into words
common_words = kmeans.cluster_centers_.argsort()[:,-1:-15:-1]
for num, centroid in enumerate(common_words):
    print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))
# Out:
# 0 : homem, onde, exército, caras, mulher, nunca, perdidos, legal, tudo, selva, aranha, eis, vai, relva
# 1 : tudo, vai, sempre, ser, mim, nada, vida, aqui, hoje, nunca, dia, mundo, assim, pode
# 2 : assim, baby, tchu, fiz, tchu tchu, bela, então, chove, tempo, baby baby, coração, pena, macaco, vai
# 3 : dia, lembro, bom, todo dia, pra ser, todo, dia dia, ainda, aqui, bom bom, ser, bom dia, vida, ser sincero
# 4 : bem, faz, ninguém, vai, ser, tão, sinto, todo, mundo, sei, quero, tudo, todo mundo, vou
# 5 : mãe, cruel, disco, agora, mãe mãe, love, mamãe, hey, atividade, show, salve, nome, uns, milhas
# 6 : quero, sei, dizer, mim, posso, ser, tudo, ver, agora, assim, vou, amo, amor, ficar
# 7 : vamos, gente, país, tudo, todos, vai, viver, então vamos, vida, dia, vamos viver, então, bom, ser
# 8 : vai, vida, nada, mundo, ninguém, dia, vem, quer, ser, aqui, agora, sei, tão, faz
# 9 : vou, vai, quero, sei, mim, onde, aqui, tudo, ser, ver, mundo, deixar, ficar, dia
# 10 : amor, mim, coração, vida, ser, tudo, vai, vou, vem, dor, amar, tão, quero, amor amor
# 11 : noite, chuva, sol, medo, caia, lua, cidade, dia, velocidade, noites, traga, sob sol, meio, todos
# 12 : sol, luz, luz sol, sol sol, paz, dia, amor, olhos, vem, vem sol, mar, vida, cidadão, sempre
# 13 : tempo, tão, vai, quanto tempo, vida, quanto, tudo, tempo tempo, faz, dias, mundo, trás, sei, agora
# 14 : gente, gente quer, vai, quer, pra gente, faz, gente vai, mundo, porque, nada, gente faz, tudo, dia, ser
# 15 : deus, senhor, jesus, aleluia, amor, cristo, deus deus, rei, viver, santo, glória, amor deus, vida, dará
# 16 : deixa, leve, dia, leve mal, outro, vai, quero, outro dia, ser, bobeira, mal, ver, hoje, vida

# %% [markdown]
# Quais são algumas músicas do grupo X?

# %%
pd.options.display.max_colwidth = 100
letras_ag.query('grupo == 1')[['SName', 'Lyric', 'Artist']].sample(20)
# Out:
#                               SName  ...           Artist
# 7180  A Minha Gratidão é Uma Pessoa  ...       Jota Quest
# 7625                 No Meio do Mar  ...            Skank
# 2215                 Diga (Parte 2)  ...           Fresno
# 1267                Chuva Quer Cair  ...     Danni Carlos
# 6948                Ton Ton O Nando  ...     Danni Carlos
# 4993                         Gospel  ...      Raul Seixas
# 6469                          Amigo  ...         Vanguart
# 2430                Tanto Quanto Eu  ...             Ira!
# 3884      Eu Não Sei Mentir Direito  ...          O Rappa
# 2445               All In Your Mind  ...      Iron Maiden
# 6377                        A Festa  ...  Ultraje A Rigor
# 5611                     Meus Medos  ...    Rosa de Saron
# 4317                         Espero  ...          Pato Fu
# 6040                    O Teu Olhar  ...           Strike
# 5605            Menos de Um Segundo  ...    Rosa de Saron
# 2399                    O Candidato  ...             Ira!
# 5652    Tudo O Que Eu Não Soube Ver  ...    Rosa de Saron
# 5724                       Pessoa x  ...              RPM
# 1478                      Mais Além  ...       Detonautas
# 1328             Canção Para Amigos  ...        Dead Fish
#
# [20 rows x 3 columns]

# %% [markdown]
# ### Artistas mais presentes em cada grupo

# %%
for g in range(0, 7):
  print('\n-----\nGRUPO {}:'.format(g))
  print(letras_ag.query('grupo ==  {}'.format(g))['Artist'].value_counts()[0:10])
  print('-----')
# Out:
# -----
# GRUPO 0:
# Erasmo Carlos            9
# Engenheiros do Hawaii    8
# Ira!                     6
# Velhas Virgens           5
# Blitz                    4
# PG                       3
# Barão Vermelho           3
# Cazuza                   3
# Raul Seixas              3
# Charlie Brown Jr         3
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 1:
# Fresno                   63
# Jota Quest               60
# Engenheiros do Hawaii    56
# Nx Zero                  54
# Lulu Santos              54
# Biquini Cavadão          48
# Capital Inicial          48
# Rosa de Saron            47
# Dead Fish                40
# CPM 22                   39
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 2:
# Lulu Santos         16
# Skank                8
# Isabella Taviani     6
# Raul Seixas          6
# Blitz                6
# Capital Inicial      5
# Rita Lee             5
# Pato Fu              4
# Velhas Virgens       4
# Leoni                4
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 3:
# Engenheiros do Hawaii    10
# CPM 22                   10
# Lulu Santos               8
# Raul Seixas               5
# Vanguart                  4
# Matanza                   4
# Biquini Cavadão           3
# Legião Urbana             3
# Reação Em Cadeia          3
# Ira!                      3
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 4:
# Lulu Santos              28
# Rodox                    20
# Charlie Brown Jr         19
# Skank                    18
# Nx Zero                  15
# Matanza                  13
# Erasmo Carlos            13
# Engenheiros do Hawaii    12
# Rita Lee                 11
# Detonautas               10
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 5:
# Blitz                    12
# Rita Lee                  7
# Engenheiros do Hawaii     6
# Velhas Virgens            5
# Pedra Letícia             4
# Lulu Santos               4
# Mutantes                  3
# Biquini Cavadão           3
# Raimundos                 3
# Raul Seixas               2
# Name: Artist, dtype: int64
# -----
#
# -----
# GRUPO 6:
# Lulu Santos         40
# Cássia Eller        28
# Esteban             26
# Detonautas          21
# Erasmo Carlos       19
# Scalene             18
# Biquini Cavadão     18
# Jota Quest          18
# Fresno              18
# Reação Em Cadeia    18
# Name: Artist, dtype: int64
# -----

# %%
letras_ag.query('Artist ==  "Raça Negra"')[['grupo', 'SName']].groupby('grupo').count()
# Out:
# Empty DataFrame
# Columns: [SName]
# Index: []

# %% [markdown]
# ## Visualizando grupos em muitas dimensões
#
# Para visualizar melhor estruturas de semelhanças nos nossos dados, precisamos que eles estejam em 2D, usaremos um método de **redução de dimensionalidade**.
#
# Os dois método mais frequentemente usados são PCA e t-SNE.

# %%
from sklearn.manifold import TSNE

letras_embedded = TSNE(n_components=2, verbose=1).fit_transform(vec_text)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7680 samples in 0.005s...
# [t-SNE] Computed neighbors for 7680 samples in 3.715s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7680
# [t-SNE] Computed conditional probabilities for sample 2000 / 7680
# [t-SNE] Computed conditional probabilities for sample 3000 / 7680
# [t-SNE] Computed conditional probabilities for sample 4000 / 7680
# [t-SNE] Computed conditional probabilities for sample 5000 / 7680
# [t-SNE] Computed conditional probabilities for sample 6000 / 7680
# [t-SNE] Computed conditional probabilities for sample 7000 / 7680
# [t-SNE] Computed conditional probabilities for sample 7680 / 7680
# [t-SNE] Mean sigma: 0.542049
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 123.271011
# [t-SNE] KL divergence after 1000 iterations: 3.824572

# %%
letras_ag = letras_ag.assign(tsne1 = letras_embedded[:,0], tsne2 = letras_embedded[:,1])

alt.Chart(letras_ag.sample(1000)).mark_circle(
    opacity = .7,
    size = 30
).encode(
    x = 'tsne1',
    y = 'tsne2', 
    color = 'grupo:N',
    tooltip = ['Artist', 'SName']
).interactive()
# Out:
# alt.Chart(...)
